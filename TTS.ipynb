# %%
#@title Setup
# !git clone https://github.com/Damarcreative/anime-tts.git
# %cd anime-tts
# !pip install -r requirements-googlecolab.txt
# !mkdir model

import matplotlib.pyplot as plt
import IPython.display as ipd

import os
import json
import math
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader

import commons
import utils
from data_utils import TextAudioLoader, TextAudioCollate, TextAudioSpeakerLoader, TextAudioSpeakerCollate
from models import SynthesizerTrn
from text.symbols import symbols
from text import text_to_sequence

from scipy.io.wavfile import write

def get_text(text, hps):
    text_norm = text_to_sequence(text, hps.data.text_cleaners)
    if hps.data.add_blank:
        text_norm = commons.intersperse(text_norm, 0)
    text_norm = torch.LongTensor(text_norm)
    return text_norm

hps = utils.get_hparams_from_file("configs/config-single-speaker.json")

net_g = SynthesizerTrn(
    len(symbols),
    hps.data.filter_length // 2 + 1,
    hps.train.segment_size // hps.data.hop_length,
    **hps.model).cuda()
_ = net_g.eval()
# Out:
# fatal: destination path 'anime-tts' already exists and is not an empty directory.
# /Users/sebh/Downloads/mikomiko-sd/anime-tts
# Requirement already satisfied: unidecode in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements-googlecolab.txt (line 1)) (1.3.8)
# Requirement already satisfied: pyopenjtalk in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements-googlecolab.txt (line 2)) (0.3.4)
# Requirement already satisfied: numpy>=1.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from pyopenjtalk->-r requirements-googlecolab.txt (line 2)) (1.26.4)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from pyopenjtalk->-r requirements-googlecolab.txt (line 2)) (4.66.5)
# mkdir: model: File exists
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=1039)
#            2	RESUME(arg=0, lineno=1039)
#            4	LOAD_FAST(arg=0, lineno=1042)
#            6	LOAD_CONST(arg=1, lineno=1042)
#            8	BINARY_SUBSCR(arg=None, lineno=1042)
#           12	LOAD_FAST(arg=0, lineno=1042)
#           14	LOAD_CONST(arg=2, lineno=1042)
#           16	BINARY_SUBSCR(arg=None, lineno=1042)
#           20	COMPARE_OP(arg=68, lineno=1042)
#           24	LOAD_FAST(arg=0, lineno=1042)
#           26	LOAD_CONST(arg=1, lineno=1042)
#           28	BINARY_SUBSCR(arg=None, lineno=1042)
#           32	LOAD_FAST(arg=0, lineno=1042)
#           34	LOAD_CONST(arg=3, lineno=1042)
#           36	BINARY_SUBSCR(arg=None, lineno=1042)
#           40	COMPARE_OP(arg=92, lineno=1042)
#           44	BINARY_OP(arg=1, lineno=1042)
#           48	RETURN_VALUE(arg=None, lineno=1042)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=1039)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=RESUME(arg=0, lineno=1039)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=1042)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_CONST(arg=1, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$x4.0']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=BINARY_SUBSCR(arg=None, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$x4.0', '$const6.1']
# DEBUG:numba.core.byteflow:dispatch pc=12, inst=LOAD_FAST(arg=0, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2']
# DEBUG:numba.core.byteflow:dispatch pc=14, inst=LOAD_CONST(arg=2, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2', '$x12.3']
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=BINARY_SUBSCR(arg=None, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2', '$x12.3', '$const14.4']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=COMPARE_OP(arg=68, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2', '$16binary_subscr.5']
# DEBUG:numba.core.byteflow:dispatch pc=24, inst=LOAD_FAST(arg=0, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6']
# DEBUG:numba.core.byteflow:dispatch pc=26, inst=LOAD_CONST(arg=1, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$x24.7']
# DEBUG:numba.core.byteflow:dispatch pc=28, inst=BINARY_SUBSCR(arg=None, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$x24.7', '$const26.8']
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=LOAD_FAST(arg=0, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$28binary_subscr.9']
# DEBUG:numba.core.byteflow:dispatch pc=34, inst=LOAD_CONST(arg=3, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$28binary_subscr.9', '$x32.10']
# DEBUG:numba.core.byteflow:dispatch pc=36, inst=BINARY_SUBSCR(arg=None, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$28binary_subscr.9', '$x32.10', '$const34.11']
# DEBUG:numba.core.byteflow:dispatch pc=40, inst=COMPARE_OP(arg=92, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$28binary_subscr.9', '$36binary_subscr.12']
# DEBUG:numba.core.byteflow:dispatch pc=44, inst=BINARY_OP(arg=1, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$40compare_op.13']
# DEBUG:numba.core.byteflow:dispatch pc=48, inst=RETURN_VALUE(arg=None, lineno=1042)
# DEBUG:numba.core.byteflow:stack ['$binop_and_44.14']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {}), (4, {'res': '$x4.0'}), (6, {'res': '$const6.1'}), (8, {'index': '$const6.1', 'target': '$x4.0', 'res': '$8binary_subscr.2'}), (12, {'res': '$x12.3'}), (14, {'res': '$const14.4'}), (16, {'index': '$const14.4', 'target': '$x12.3', 'res': '$16binary_subscr.5'}), (20, {'lhs': '$8binary_subscr.2', 'rhs': '$16binary_subscr.5', 'res': '$20compare_op.6'}), (24, {'res': '$x24.7'}), (26, {'res': '$const26.8'}), (28, {'index': '$const26.8', 'target': '$x24.7', 'res': '$28binary_subscr.9'}), (32, {'res': '$x32.10'}), (34, {'res': '$const34.11'}), (36, {'index': '$const34.11', 'target': '$x32.10', 'res': '$36binary_subscr.12'}), (40, {'lhs': '$28binary_subscr.9', 'rhs': '$36binary_subscr.12', 'res': '$40compare_op.13'}), (44, {'op': '&', 'lhs': '$20compare_op.6', 'rhs': '$40compare_op.13', 'res': '$binop_and_44.14'}), (48, {'retval': '$binop_and_44.14', 'castval': '$48return_value.15'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     x = arg(0, name=x)                       ['x']
#     $const6.1 = const(int, 0)                ['$const6.1']
#     $8binary_subscr.2 = getitem(value=x, index=$const6.1, fn=<built-in function getitem>) ['$8binary_subscr.2', '$const6.1', 'x']
#     $const14.4 = const(int, -1)              ['$const14.4']
#     $16binary_subscr.5 = getitem(value=x, index=$const14.4, fn=<built-in function getitem>) ['$16binary_subscr.5', '$const14.4', 'x']
#     $20compare_op.6 = $8binary_subscr.2 > $16binary_subscr.5 ['$16binary_subscr.5', '$20compare_op.6', '$8binary_subscr.2']
#     $const26.8 = const(int, 0)               ['$const26.8']
#     $28binary_subscr.9 = getitem(value=x, index=$const26.8, fn=<built-in function getitem>) ['$28binary_subscr.9', '$const26.8', 'x']
#     $const34.11 = const(int, 1)              ['$const34.11']
#     $36binary_subscr.12 = getitem(value=x, index=$const34.11, fn=<built-in function getitem>) ['$36binary_subscr.12', '$const34.11', 'x']
#     $40compare_op.13 = $28binary_subscr.9 >= $36binary_subscr.12 ['$28binary_subscr.9', '$36binary_subscr.12', '$40compare_op.13']
#     $binop_and_44.14 = $20compare_op.6 & $40compare_op.13 ['$20compare_op.6', '$40compare_op.13', '$binop_and_44.14']
#     $48return_value.15 = cast(value=$binop_and_44.14) ['$48return_value.15', '$binop_and_44.14']
#     return $48return_value.15                ['$48return_value.15']
#
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=1045)
#            2	RESUME(arg=0, lineno=1045)
#            4	LOAD_FAST(arg=0, lineno=1048)
#            6	LOAD_CONST(arg=1, lineno=1048)
#            8	BINARY_SUBSCR(arg=None, lineno=1048)
#           12	LOAD_FAST(arg=0, lineno=1048)
#           14	LOAD_CONST(arg=2, lineno=1048)
#           16	BINARY_SUBSCR(arg=None, lineno=1048)
#           20	COMPARE_OP(arg=2, lineno=1048)
#           24	LOAD_FAST(arg=0, lineno=1048)
#           26	LOAD_CONST(arg=1, lineno=1048)
#           28	BINARY_SUBSCR(arg=None, lineno=1048)
#           32	LOAD_FAST(arg=0, lineno=1048)
#           34	LOAD_CONST(arg=3, lineno=1048)
#           36	BINARY_SUBSCR(arg=None, lineno=1048)
#           40	COMPARE_OP(arg=26, lineno=1048)
#           44	BINARY_OP(arg=1, lineno=1048)
#           48	RETURN_VALUE(arg=None, lineno=1048)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=1045)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=RESUME(arg=0, lineno=1045)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=1048)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_CONST(arg=1, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$x4.0']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=BINARY_SUBSCR(arg=None, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$x4.0', '$const6.1']
# DEBUG:numba.core.byteflow:dispatch pc=12, inst=LOAD_FAST(arg=0, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2']
# DEBUG:numba.core.byteflow:dispatch pc=14, inst=LOAD_CONST(arg=2, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2', '$x12.3']
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=BINARY_SUBSCR(arg=None, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2', '$x12.3', '$const14.4']
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=COMPARE_OP(arg=2, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$8binary_subscr.2', '$16binary_subscr.5']
# DEBUG:numba.core.byteflow:dispatch pc=24, inst=LOAD_FAST(arg=0, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6']
# DEBUG:numba.core.byteflow:dispatch pc=26, inst=LOAD_CONST(arg=1, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$x24.7']
# DEBUG:numba.core.byteflow:dispatch pc=28, inst=BINARY_SUBSCR(arg=None, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$x24.7', '$const26.8']
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=LOAD_FAST(arg=0, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$28binary_subscr.9']
# DEBUG:numba.core.byteflow:dispatch pc=34, inst=LOAD_CONST(arg=3, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$28binary_subscr.9', '$x32.10']
# DEBUG:numba.core.byteflow:dispatch pc=36, inst=BINARY_SUBSCR(arg=None, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$28binary_subscr.9', '$x32.10', '$const34.11']
# DEBUG:numba.core.byteflow:dispatch pc=40, inst=COMPARE_OP(arg=26, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$28binary_subscr.9', '$36binary_subscr.12']
# DEBUG:numba.core.byteflow:dispatch pc=44, inst=BINARY_OP(arg=1, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$20compare_op.6', '$40compare_op.13']
# DEBUG:numba.core.byteflow:dispatch pc=48, inst=RETURN_VALUE(arg=None, lineno=1048)
# DEBUG:numba.core.byteflow:stack ['$binop_and_44.14']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>, {})
# DEBUG:numba.core.byteflow:keep phismap: {}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>, {})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {}), (4, {'res': '$x4.0'}), (6, {'res': '$const6.1'}), (8, {'index': '$const6.1', 'target': '$x4.0', 'res': '$8binary_subscr.2'}), (12, {'res': '$x12.3'}), (14, {'res': '$const14.4'}), (16, {'index': '$const14.4', 'target': '$x12.3', 'res': '$16binary_subscr.5'}), (20, {'lhs': '$8binary_subscr.2', 'rhs': '$16binary_subscr.5', 'res': '$20compare_op.6'}), (24, {'res': '$x24.7'}), (26, {'res': '$const26.8'}), (28, {'index': '$const26.8', 'target': '$x24.7', 'res': '$28binary_subscr.9'}), (32, {'res': '$x32.10'}), (34, {'res': '$const34.11'}), (36, {'index': '$const34.11', 'target': '$x32.10', 'res': '$36binary_subscr.12'}), (40, {'lhs': '$28binary_subscr.9', 'rhs': '$36binary_subscr.12', 'res': '$40compare_op.13'}), (44, {'op': '&', 'lhs': '$20compare_op.6', 'rhs': '$40compare_op.13', 'res': '$binop_and_44.14'}), (48, {'retval': '$binop_and_44.14', 'castval': '$48return_value.15'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     x = arg(0, name=x)                       ['x']
#     $const6.1 = const(int, 0)                ['$const6.1']
#     $8binary_subscr.2 = getitem(value=x, index=$const6.1, fn=<built-in function getitem>) ['$8binary_subscr.2', '$const6.1', 'x']
#     $const14.4 = const(int, -1)              ['$const14.4']
#     $16binary_subscr.5 = getitem(value=x, index=$const14.4, fn=<built-in function getitem>) ['$16binary_subscr.5', '$const14.4', 'x']
#     $20compare_op.6 = $8binary_subscr.2 < $16binary_subscr.5 ['$16binary_subscr.5', '$20compare_op.6', '$8binary_subscr.2']
#     $const26.8 = const(int, 0)               ['$const26.8']
#     $28binary_subscr.9 = getitem(value=x, index=$const26.8, fn=<built-in function getitem>) ['$28binary_subscr.9', '$const26.8', 'x']
#     $const34.11 = const(int, 1)              ['$const34.11']
#     $36binary_subscr.12 = getitem(value=x, index=$const34.11, fn=<built-in function getitem>) ['$36binary_subscr.12', '$const34.11', 'x']
#     $40compare_op.13 = $28binary_subscr.9 <= $36binary_subscr.12 ['$28binary_subscr.9', '$36binary_subscr.12', '$40compare_op.13']
#     $binop_and_44.14 = $20compare_op.6 & $40compare_op.13 ['$20compare_op.6', '$40compare_op.13', '$binop_and_44.14']
#     $48return_value.15 = cast(value=$binop_and_44.14) ['$48return_value.15', '$binop_and_44.14']
#     return $48return_value.15                ['$48return_value.15']
#
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=3)
#            2	RESUME(arg=0, lineno=3)
#            4	LOAD_FAST(arg=0, lineno=6)
#            6	LOAD_ATTR(arg=0, lineno=6)
#           26	LOAD_CONST(arg=1, lineno=6)
#           28	BINARY_SUBSCR(arg=None, lineno=6)
#           32	STORE_FAST(arg=4, lineno=6)
#           34	LOAD_CONST(arg=2, lineno=7)
#           36	STORE_FAST(arg=5, lineno=7)
#           38	LOAD_GLOBAL(arg=3, lineno=8)
#           48	LOAD_GLOBAL(arg=5, lineno=8)
#           58	LOAD_FAST(arg=4, lineno=8)
#           60	CALL(arg=1, lineno=8)
#           68	CALL(arg=1, lineno=8)
#           76	GET_ITER(arg=None, lineno=8)
# >         78	FOR_ITER(arg=234, lineno=8)
#           82	STORE_FAST(arg=6, lineno=8)
#           84	LOAD_FAST(arg=0, lineno=9)
#           86	LOAD_FAST(arg=6, lineno=9)
#           88	BINARY_SUBSCR(arg=None, lineno=9)
#           92	STORE_FAST(arg=7, lineno=9)
#           94	LOAD_FAST(arg=1, lineno=10)
#           96	LOAD_FAST(arg=6, lineno=10)
#           98	BINARY_SUBSCR(arg=None, lineno=10)
#          102	STORE_FAST(arg=8, lineno=10)
#          104	LOAD_FAST(arg=2, lineno=11)
#          106	LOAD_FAST(arg=6, lineno=11)
#          108	BINARY_SUBSCR(arg=None, lineno=11)
#          112	STORE_FAST(arg=9, lineno=11)
#          114	LOAD_FAST(arg=3, lineno=12)
#          116	LOAD_FAST(arg=6, lineno=12)
#          118	BINARY_SUBSCR(arg=None, lineno=12)
#          122	STORE_FAST(arg=10, lineno=12)
#          124	LOAD_CONST(arg=3, lineno=14)
#          126	COPY(arg=1, lineno=14)
#          128	STORE_FAST(arg=11, lineno=14)
#          130	STORE_FAST(arg=12, lineno=14)
#          132	LOAD_FAST(arg=10, lineno=15)
#          134	LOAD_CONST(arg=4, lineno=15)
#          136	BINARY_OP(arg=10, lineno=15)
#          140	STORE_FAST(arg=13, lineno=15)
#          142	LOAD_GLOBAL(arg=3, lineno=17)
#          152	LOAD_FAST(arg=9, lineno=17)
#          154	CALL(arg=1, lineno=17)
#          162	GET_ITER(arg=None, lineno=17)
# >        164	FOR_ITER(arg=120, lineno=17)
#          168	STORE_FAST(arg=14, lineno=17)
#          170	LOAD_GLOBAL(arg=3, lineno=18)
#          180	LOAD_GLOBAL(arg=7, lineno=18)
#          190	LOAD_CONST(arg=1, lineno=18)
#          192	LOAD_FAST(arg=10, lineno=18)
#          194	LOAD_FAST(arg=14, lineno=18)
#          196	BINARY_OP(arg=0, lineno=18)
#          200	LOAD_FAST(arg=9, lineno=18)
#          202	BINARY_OP(arg=10, lineno=18)
#          206	CALL(arg=2, lineno=18)
#          214	LOAD_GLOBAL(arg=9, lineno=18)
#          224	LOAD_FAST(arg=10, lineno=18)
#          226	LOAD_FAST(arg=14, lineno=18)
#          228	LOAD_CONST(arg=4, lineno=18)
#          230	BINARY_OP(arg=0, lineno=18)
#          234	CALL(arg=2, lineno=18)
#          242	CALL(arg=2, lineno=18)
#          250	GET_ITER(arg=None, lineno=18)
# >        252	FOR_ITER(arg=74, lineno=18)
#          256	STORE_FAST(arg=15, lineno=18)
#          258	LOAD_FAST(arg=15, lineno=19)
#          260	LOAD_FAST(arg=14, lineno=19)
#          262	COMPARE_OP(arg=40, lineno=19)
#          266	POP_JUMP_IF_FALSE(arg=3, lineno=19)
#          268	LOAD_FAST(arg=5, lineno=20)
#          270	STORE_FAST(arg=12, lineno=20)
#          272	JUMP_FORWARD(arg=10, lineno=20)
# >        274	LOAD_FAST(arg=8, lineno=22)
#          276	LOAD_FAST(arg=14, lineno=22)
#          278	LOAD_CONST(arg=4, lineno=22)
#          280	BINARY_OP(arg=10, lineno=22)
#          284	LOAD_FAST(arg=15, lineno=22)
#          286	BUILD_TUPLE(arg=2, lineno=22)
#          288	BINARY_SUBSCR(arg=None, lineno=22)
#          292	STORE_FAST(arg=12, lineno=22)
# >        294	LOAD_FAST(arg=15, lineno=23)
#          296	LOAD_CONST(arg=1, lineno=23)
#          298	COMPARE_OP(arg=40, lineno=23)
#          302	POP_JUMP_IF_FALSE(arg=11, lineno=23)
#          304	LOAD_FAST(arg=14, lineno=24)
#          306	LOAD_CONST(arg=1, lineno=24)
#          308	COMPARE_OP(arg=40, lineno=24)
#          312	POP_JUMP_IF_FALSE(arg=3, lineno=24)
#          314	LOAD_CONST(arg=3, lineno=25)
#          316	STORE_FAST(arg=11, lineno=25)
#          318	JUMP_FORWARD(arg=16, lineno=25)
# >        320	LOAD_FAST(arg=5, lineno=27)
#          322	STORE_FAST(arg=11, lineno=27)
#          324	JUMP_FORWARD(arg=13, lineno=27)
# >        326	LOAD_FAST(arg=8, lineno=29)
#          328	LOAD_FAST(arg=14, lineno=29)
#          330	LOAD_CONST(arg=4, lineno=29)
#          332	BINARY_OP(arg=10, lineno=29)
#          336	LOAD_FAST(arg=15, lineno=29)
#          338	LOAD_CONST(arg=4, lineno=29)
#          340	BINARY_OP(arg=10, lineno=29)
#          344	BUILD_TUPLE(arg=2, lineno=29)
#          346	BINARY_SUBSCR(arg=None, lineno=29)
#          350	STORE_FAST(arg=11, lineno=29)
# >        352	LOAD_FAST(arg=8, lineno=30)
#          354	LOAD_FAST(arg=14, lineno=30)
#          356	LOAD_FAST(arg=15, lineno=30)
#          358	BUILD_TUPLE(arg=2, lineno=30)
#          360	COPY(arg=2, lineno=30)
#          362	COPY(arg=2, lineno=30)
#          364	BINARY_SUBSCR(arg=None, lineno=30)
#          368	LOAD_GLOBAL(arg=7, lineno=30)
#          378	LOAD_FAST(arg=11, lineno=30)
#          380	LOAD_FAST(arg=12, lineno=30)
#          382	CALL(arg=2, lineno=30)
#          390	BINARY_OP(arg=13, lineno=30)
#          394	SWAP(arg=3, lineno=30)
#          396	SWAP(arg=2, lineno=30)
#          398	STORE_SUBSCR(arg=None, lineno=30)
#          402	JUMP_BACKWARD(arg=76, lineno=30)
# >        404	END_FOR(arg=None, lineno=18)
#          406	JUMP_BACKWARD(arg=122, lineno=18)
# >        408	END_FOR(arg=None, lineno=17)
#          410	LOAD_GLOBAL(arg=3, lineno=32)
#          420	LOAD_FAST(arg=9, lineno=32)
#          422	LOAD_CONST(arg=4, lineno=32)
#          424	BINARY_OP(arg=10, lineno=32)
#          428	LOAD_CONST(arg=5, lineno=32)
#          430	LOAD_CONST(arg=5, lineno=32)
#          432	CALL(arg=3, lineno=32)
#          440	GET_ITER(arg=None, lineno=32)
# >        442	FOR_ITER(arg=50, lineno=32)
#          446	STORE_FAST(arg=14, lineno=32)
#          448	LOAD_CONST(arg=4, lineno=33)
#          450	LOAD_FAST(arg=7, lineno=33)
#          452	LOAD_FAST(arg=14, lineno=33)
#          454	LOAD_FAST(arg=13, lineno=33)
#          456	BUILD_TUPLE(arg=2, lineno=33)
#          458	STORE_SUBSCR(arg=None, lineno=33)
#          462	LOAD_FAST(arg=13, lineno=34)
#          464	LOAD_CONST(arg=1, lineno=34)
#          466	COMPARE_OP(arg=55, lineno=34)
#          470	POP_JUMP_IF_TRUE(arg=1, lineno=34)
#          472	JUMP_BACKWARD(arg=16, lineno=34)
# >        474	LOAD_FAST(arg=13, lineno=34)
#          476	LOAD_FAST(arg=14, lineno=34)
#          478	COMPARE_OP(arg=40, lineno=34)
#          482	POP_JUMP_IF_TRUE(arg=25, lineno=34)
#          484	LOAD_FAST(arg=8, lineno=34)
#          486	LOAD_FAST(arg=14, lineno=34)
#          488	LOAD_CONST(arg=4, lineno=34)
#          490	BINARY_OP(arg=10, lineno=34)
#          494	LOAD_FAST(arg=13, lineno=34)
#          496	BUILD_TUPLE(arg=2, lineno=34)
#          498	BINARY_SUBSCR(arg=None, lineno=34)
#          502	LOAD_FAST(arg=8, lineno=34)
#          504	LOAD_FAST(arg=14, lineno=34)
#          506	LOAD_CONST(arg=4, lineno=34)
#          508	BINARY_OP(arg=10, lineno=34)
#          512	LOAD_FAST(arg=13, lineno=34)
#          514	LOAD_CONST(arg=4, lineno=34)
#          516	BINARY_OP(arg=10, lineno=34)
#          520	BUILD_TUPLE(arg=2, lineno=34)
#          522	BINARY_SUBSCR(arg=None, lineno=34)
#          526	COMPARE_OP(arg=2, lineno=34)
#          530	POP_JUMP_IF_TRUE(arg=1, lineno=34)
#          532	JUMP_BACKWARD(arg=46, lineno=34)
# >        534	LOAD_FAST(arg=13, lineno=35)
#          536	LOAD_CONST(arg=4, lineno=35)
#          538	BINARY_OP(arg=10, lineno=35)
#          542	STORE_FAST(arg=13, lineno=35)
#          544	JUMP_BACKWARD(arg=52, lineno=35)
# >        546	END_FOR(arg=None, lineno=32)
#          548	JUMP_BACKWARD(arg=236, lineno=32)
# >        550	END_FOR(arg=None, lineno=8)
#          552	RETURN_CONST(arg=0, lineno=8)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=3)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=RESUME(arg=0, lineno=3)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=6)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_ATTR(arg=0, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$paths4.0']
# DEBUG:numba.core.byteflow:dispatch pc=26, inst=LOAD_CONST(arg=1, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$6load_attr.1']
# DEBUG:numba.core.byteflow:dispatch pc=28, inst=BINARY_SUBSCR(arg=None, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$6load_attr.1', '$const26.2']
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=STORE_FAST(arg=4, lineno=6)
# DEBUG:numba.core.byteflow:stack ['$28binary_subscr.3']
# DEBUG:numba.core.byteflow:dispatch pc=34, inst=LOAD_CONST(arg=2, lineno=7)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=36, inst=STORE_FAST(arg=5, lineno=7)
# DEBUG:numba.core.byteflow:stack ['$const34.4']
# DEBUG:numba.core.byteflow:dispatch pc=38, inst=LOAD_GLOBAL(arg=3, lineno=8)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=48, inst=LOAD_GLOBAL(arg=5, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$null$38.6', '$38load_global.5']
# DEBUG:numba.core.byteflow:dispatch pc=58, inst=LOAD_FAST(arg=4, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$null$38.6', '$38load_global.5', '$null$48.8', '$48load_global.7']
# DEBUG:numba.core.byteflow:dispatch pc=60, inst=CALL(arg=1, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$null$38.6', '$38load_global.5', '$null$48.8', '$48load_global.7', '$b58.9']
# DEBUG:numba.core.byteflow:dispatch pc=68, inst=CALL(arg=1, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$null$38.6', '$38load_global.5', '$60call.10']
# DEBUG:numba.core.byteflow:dispatch pc=76, inst=GET_ITER(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$68call.11']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=78, stack=('$76get_iter.12',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=78 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi78.0']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=78 nstack_initial=1)
# DEBUG:numba.core.byteflow:dispatch pc=78, inst=FOR_ITER(arg=234, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$phi78.0']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=550, stack=('$phi78.0', '$78for_iter.2'), blockstack=(), npush=0), Edge(pc=82, stack=('$phi78.0', '$78for_iter.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=550 nstack_initial=2), State(pc_initial=82 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi550.0', '$phi550.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=550 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=550, inst=END_FOR(arg=None, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$phi550.0', '$phi550.1']
# DEBUG:numba.core.byteflow:dispatch pc=552, inst=RETURN_CONST(arg=0, lineno=8)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=82 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi82.0', '$phi82.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=82 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=82, inst=STORE_FAST(arg=6, lineno=8)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$phi82.1']
# DEBUG:numba.core.byteflow:dispatch pc=84, inst=LOAD_FAST(arg=0, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$phi82.0']
# DEBUG:numba.core.byteflow:dispatch pc=86, inst=LOAD_FAST(arg=6, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$paths84.2']
# DEBUG:numba.core.byteflow:dispatch pc=88, inst=BINARY_SUBSCR(arg=None, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$paths84.2', '$i86.3']
# DEBUG:numba.core.byteflow:dispatch pc=92, inst=STORE_FAST(arg=7, lineno=9)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$88binary_subscr.4']
# DEBUG:numba.core.byteflow:dispatch pc=94, inst=LOAD_FAST(arg=1, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$phi82.0']
# DEBUG:numba.core.byteflow:dispatch pc=96, inst=LOAD_FAST(arg=6, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$values94.5']
# DEBUG:numba.core.byteflow:dispatch pc=98, inst=BINARY_SUBSCR(arg=None, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$values94.5', '$i96.6']
# DEBUG:numba.core.byteflow:dispatch pc=102, inst=STORE_FAST(arg=8, lineno=10)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$98binary_subscr.7']
# DEBUG:numba.core.byteflow:dispatch pc=104, inst=LOAD_FAST(arg=2, lineno=11)
# DEBUG:numba.core.byteflow:stack ['$phi82.0']
# DEBUG:numba.core.byteflow:dispatch pc=106, inst=LOAD_FAST(arg=6, lineno=11)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$t_ys104.8']
# DEBUG:numba.core.byteflow:dispatch pc=108, inst=BINARY_SUBSCR(arg=None, lineno=11)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$t_ys104.8', '$i106.9']
# DEBUG:numba.core.byteflow:dispatch pc=112, inst=STORE_FAST(arg=9, lineno=11)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$108binary_subscr.10']
# DEBUG:numba.core.byteflow:dispatch pc=114, inst=LOAD_FAST(arg=3, lineno=12)
# DEBUG:numba.core.byteflow:stack ['$phi82.0']
# DEBUG:numba.core.byteflow:dispatch pc=116, inst=LOAD_FAST(arg=6, lineno=12)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$t_xs114.11']
# DEBUG:numba.core.byteflow:dispatch pc=118, inst=BINARY_SUBSCR(arg=None, lineno=12)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$t_xs114.11', '$i116.12']
# DEBUG:numba.core.byteflow:dispatch pc=122, inst=STORE_FAST(arg=10, lineno=12)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$118binary_subscr.13']
# DEBUG:numba.core.byteflow:dispatch pc=124, inst=LOAD_CONST(arg=3, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$phi82.0']
# DEBUG:numba.core.byteflow:dispatch pc=126, inst=COPY(arg=1, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$const124.14']
# DEBUG:numba.core.byteflow:dispatch pc=128, inst=STORE_FAST(arg=11, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$const124.14', '$const124.14']
# DEBUG:numba.core.byteflow:dispatch pc=130, inst=STORE_FAST(arg=12, lineno=14)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$const124.14']
# DEBUG:numba.core.byteflow:dispatch pc=132, inst=LOAD_FAST(arg=10, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$phi82.0']
# DEBUG:numba.core.byteflow:dispatch pc=134, inst=LOAD_CONST(arg=4, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$t_x132.15']
# DEBUG:numba.core.byteflow:dispatch pc=136, inst=BINARY_OP(arg=10, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$t_x132.15', '$const134.16']
# DEBUG:numba.core.byteflow:dispatch pc=140, inst=STORE_FAST(arg=13, lineno=15)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$binop_sub136.17']
# DEBUG:numba.core.byteflow:dispatch pc=142, inst=LOAD_GLOBAL(arg=3, lineno=17)
# DEBUG:numba.core.byteflow:stack ['$phi82.0']
# DEBUG:numba.core.byteflow:dispatch pc=152, inst=LOAD_FAST(arg=9, lineno=17)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$null$142.19', '$142load_global.18']
# DEBUG:numba.core.byteflow:dispatch pc=154, inst=CALL(arg=1, lineno=17)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$null$142.19', '$142load_global.18', '$t_y152.20']
# DEBUG:numba.core.byteflow:dispatch pc=162, inst=GET_ITER(arg=None, lineno=17)
# DEBUG:numba.core.byteflow:stack ['$phi82.0', '$154call.21']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=164, stack=('$phi82.0', '$162get_iter.22'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=164 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi164.0', '$phi164.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=164 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=164, inst=FOR_ITER(arg=120, lineno=17)
# DEBUG:numba.core.byteflow:stack ['$phi164.0', '$phi164.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=408, stack=('$phi164.0', '$phi164.1', '$164for_iter.3'), blockstack=(), npush=0), Edge(pc=168, stack=('$phi164.0', '$phi164.1', '$164for_iter.3'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=408 nstack_initial=3), State(pc_initial=168 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi408.0', '$phi408.1', '$phi408.2']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=408 nstack_initial=3)
# DEBUG:numba.core.byteflow:dispatch pc=408, inst=END_FOR(arg=None, lineno=17)
# DEBUG:numba.core.byteflow:stack ['$phi408.0', '$phi408.1', '$phi408.2']
# DEBUG:numba.core.byteflow:dispatch pc=410, inst=LOAD_GLOBAL(arg=3, lineno=32)
# DEBUG:numba.core.byteflow:stack ['$phi408.0']
# DEBUG:numba.core.byteflow:dispatch pc=420, inst=LOAD_FAST(arg=9, lineno=32)
# DEBUG:numba.core.byteflow:stack ['$phi408.0', '$null$410.4', '$410load_global.3']
# DEBUG:numba.core.byteflow:dispatch pc=422, inst=LOAD_CONST(arg=4, lineno=32)
# DEBUG:numba.core.byteflow:stack ['$phi408.0', '$null$410.4', '$410load_global.3', '$t_y420.5']
# DEBUG:numba.core.byteflow:dispatch pc=424, inst=BINARY_OP(arg=10, lineno=32)
# DEBUG:numba.core.byteflow:stack ['$phi408.0', '$null$410.4', '$410load_global.3', '$t_y420.5', '$const422.6']
# DEBUG:numba.core.byteflow:dispatch pc=428, inst=LOAD_CONST(arg=5, lineno=32)
# DEBUG:numba.core.byteflow:stack ['$phi408.0', '$null$410.4', '$410load_global.3', '$binop_sub424.7']
# DEBUG:numba.core.byteflow:dispatch pc=430, inst=LOAD_CONST(arg=5, lineno=32)
# DEBUG:numba.core.byteflow:stack ['$phi408.0', '$null$410.4', '$410load_global.3', '$binop_sub424.7', '$const428.8']
# DEBUG:numba.core.byteflow:dispatch pc=432, inst=CALL(arg=3, lineno=32)
# DEBUG:numba.core.byteflow:stack ['$phi408.0', '$null$410.4', '$410load_global.3', '$binop_sub424.7', '$const428.8', '$const430.9']
# DEBUG:numba.core.byteflow:dispatch pc=440, inst=GET_ITER(arg=None, lineno=32)
# DEBUG:numba.core.byteflow:stack ['$phi408.0', '$432call.10']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=442, stack=('$phi408.0', '$440get_iter.11'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=168 nstack_initial=3), State(pc_initial=442 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi168.0', '$phi168.1', '$phi168.2']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=168 nstack_initial=3)
# DEBUG:numba.core.byteflow:dispatch pc=168, inst=STORE_FAST(arg=14, lineno=17)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$phi168.2']
# DEBUG:numba.core.byteflow:dispatch pc=170, inst=LOAD_GLOBAL(arg=3, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1']
# DEBUG:numba.core.byteflow:dispatch pc=180, inst=LOAD_GLOBAL(arg=7, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3']
# DEBUG:numba.core.byteflow:dispatch pc=190, inst=LOAD_CONST(arg=1, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$null$180.6', '$180load_global.5']
# DEBUG:numba.core.byteflow:dispatch pc=192, inst=LOAD_FAST(arg=10, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$null$180.6', '$180load_global.5', '$const190.7']
# DEBUG:numba.core.byteflow:dispatch pc=194, inst=LOAD_FAST(arg=14, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$null$180.6', '$180load_global.5', '$const190.7', '$t_x192.8']
# DEBUG:numba.core.byteflow:dispatch pc=196, inst=BINARY_OP(arg=0, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$null$180.6', '$180load_global.5', '$const190.7', '$t_x192.8', '$y194.9']
# DEBUG:numba.core.byteflow:dispatch pc=200, inst=LOAD_FAST(arg=9, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$null$180.6', '$180load_global.5', '$const190.7', '$binop_add196.10']
# DEBUG:numba.core.byteflow:dispatch pc=202, inst=BINARY_OP(arg=10, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$null$180.6', '$180load_global.5', '$const190.7', '$binop_add196.10', '$t_y200.11']
# DEBUG:numba.core.byteflow:dispatch pc=206, inst=CALL(arg=2, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$null$180.6', '$180load_global.5', '$const190.7', '$binop_sub202.12']
# DEBUG:numba.core.byteflow:dispatch pc=214, inst=LOAD_GLOBAL(arg=9, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$206call.13']
# DEBUG:numba.core.byteflow:dispatch pc=224, inst=LOAD_FAST(arg=10, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$206call.13', '$null$214.15', '$214load_global.14']
# DEBUG:numba.core.byteflow:dispatch pc=226, inst=LOAD_FAST(arg=14, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$206call.13', '$null$214.15', '$214load_global.14', '$t_x224.16']
# DEBUG:numba.core.byteflow:dispatch pc=228, inst=LOAD_CONST(arg=4, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$206call.13', '$null$214.15', '$214load_global.14', '$t_x224.16', '$y226.17']
# DEBUG:numba.core.byteflow:dispatch pc=230, inst=BINARY_OP(arg=0, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$206call.13', '$null$214.15', '$214load_global.14', '$t_x224.16', '$y226.17', '$const228.18']
# DEBUG:numba.core.byteflow:dispatch pc=234, inst=CALL(arg=2, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$206call.13', '$null$214.15', '$214load_global.14', '$t_x224.16', '$binop_add230.19']
# DEBUG:numba.core.byteflow:dispatch pc=242, inst=CALL(arg=2, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$null$170.4', '$170load_global.3', '$206call.13', '$234call.20']
# DEBUG:numba.core.byteflow:dispatch pc=250, inst=GET_ITER(arg=None, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi168.0', '$phi168.1', '$242call.21']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=252, stack=('$phi168.0', '$phi168.1', '$250get_iter.22'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=442 nstack_initial=2), State(pc_initial=252 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi442.0', '$phi442.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=442 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=442, inst=FOR_ITER(arg=50, lineno=32)
# DEBUG:numba.core.byteflow:stack ['$phi442.0', '$phi442.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=546, stack=('$phi442.0', '$phi442.1', '$442for_iter.3'), blockstack=(), npush=0), Edge(pc=446, stack=('$phi442.0', '$phi442.1', '$442for_iter.3'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=252 nstack_initial=3), State(pc_initial=546 nstack_initial=3), State(pc_initial=446 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi252.0', '$phi252.1', '$phi252.2']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=252 nstack_initial=3)
# DEBUG:numba.core.byteflow:dispatch pc=252, inst=FOR_ITER(arg=74, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi252.0', '$phi252.1', '$phi252.2']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=404, stack=('$phi252.0', '$phi252.1', '$phi252.2', '$252for_iter.4'), blockstack=(), npush=0), Edge(pc=256, stack=('$phi252.0', '$phi252.1', '$phi252.2', '$252for_iter.4'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=546 nstack_initial=3), State(pc_initial=446 nstack_initial=3), State(pc_initial=404 nstack_initial=4), State(pc_initial=256 nstack_initial=4)])
# DEBUG:numba.core.byteflow:stack: ['$phi546.0', '$phi546.1', '$phi546.2']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=546 nstack_initial=3)
# DEBUG:numba.core.byteflow:dispatch pc=546, inst=END_FOR(arg=None, lineno=32)
# DEBUG:numba.core.byteflow:stack ['$phi546.0', '$phi546.1', '$phi546.2']
# DEBUG:numba.core.byteflow:dispatch pc=548, inst=JUMP_BACKWARD(arg=236, lineno=32)
# DEBUG:numba.core.byteflow:stack ['$phi546.0']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=78, stack=('$phi546.0',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=446 nstack_initial=3), State(pc_initial=404 nstack_initial=4), State(pc_initial=256 nstack_initial=4), State(pc_initial=78 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi446.0', '$phi446.1', '$phi446.2']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=446 nstack_initial=3)
# DEBUG:numba.core.byteflow:dispatch pc=446, inst=STORE_FAST(arg=14, lineno=32)
# DEBUG:numba.core.byteflow:stack ['$phi446.0', '$phi446.1', '$phi446.2']
# DEBUG:numba.core.byteflow:dispatch pc=448, inst=LOAD_CONST(arg=4, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi446.0', '$phi446.1']
# DEBUG:numba.core.byteflow:dispatch pc=450, inst=LOAD_FAST(arg=7, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi446.0', '$phi446.1', '$const448.3']
# DEBUG:numba.core.byteflow:dispatch pc=452, inst=LOAD_FAST(arg=14, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi446.0', '$phi446.1', '$const448.3', '$path450.4']
# DEBUG:numba.core.byteflow:dispatch pc=454, inst=LOAD_FAST(arg=13, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi446.0', '$phi446.1', '$const448.3', '$path450.4', '$y452.5']
# DEBUG:numba.core.byteflow:dispatch pc=456, inst=BUILD_TUPLE(arg=2, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi446.0', '$phi446.1', '$const448.3', '$path450.4', '$y452.5', '$index454.6']
# DEBUG:numba.core.byteflow:dispatch pc=458, inst=STORE_SUBSCR(arg=None, lineno=33)
# DEBUG:numba.core.byteflow:stack ['$phi446.0', '$phi446.1', '$const448.3', '$path450.4', '$456build_tuple.7']
# DEBUG:numba.core.byteflow:dispatch pc=462, inst=LOAD_FAST(arg=13, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi446.0', '$phi446.1']
# DEBUG:numba.core.byteflow:dispatch pc=464, inst=LOAD_CONST(arg=1, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi446.0', '$phi446.1', '$index462.8']
# DEBUG:numba.core.byteflow:dispatch pc=466, inst=COMPARE_OP(arg=55, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi446.0', '$phi446.1', '$index462.8', '$const464.9']
# DEBUG:numba.core.byteflow:dispatch pc=470, inst=POP_JUMP_IF_TRUE(arg=1, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi446.0', '$phi446.1', '$466compare_op.10']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=472, stack=('$phi446.0', '$phi446.1'), blockstack=(), npush=0), Edge(pc=474, stack=('$phi446.0', '$phi446.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=404 nstack_initial=4), State(pc_initial=256 nstack_initial=4), State(pc_initial=78 nstack_initial=1), State(pc_initial=472 nstack_initial=2), State(pc_initial=474 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi404.0', '$phi404.1', '$phi404.2', '$phi404.3']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=404 nstack_initial=4)
# DEBUG:numba.core.byteflow:dispatch pc=404, inst=END_FOR(arg=None, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi404.0', '$phi404.1', '$phi404.2', '$phi404.3']
# DEBUG:numba.core.byteflow:dispatch pc=406, inst=JUMP_BACKWARD(arg=122, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi404.0', '$phi404.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=164, stack=('$phi404.0', '$phi404.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=256 nstack_initial=4), State(pc_initial=78 nstack_initial=1), State(pc_initial=472 nstack_initial=2), State(pc_initial=474 nstack_initial=2), State(pc_initial=164 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi256.0', '$phi256.1', '$phi256.2', '$phi256.3']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=256 nstack_initial=4)
# DEBUG:numba.core.byteflow:dispatch pc=256, inst=STORE_FAST(arg=15, lineno=18)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$phi256.2', '$phi256.3']
# DEBUG:numba.core.byteflow:dispatch pc=258, inst=LOAD_FAST(arg=15, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$phi256.2']
# DEBUG:numba.core.byteflow:dispatch pc=260, inst=LOAD_FAST(arg=14, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$phi256.2', '$x258.4']
# DEBUG:numba.core.byteflow:dispatch pc=262, inst=COMPARE_OP(arg=40, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$phi256.2', '$x258.4', '$y260.5']
# DEBUG:numba.core.byteflow:dispatch pc=266, inst=POP_JUMP_IF_FALSE(arg=3, lineno=19)
# DEBUG:numba.core.byteflow:stack ['$phi256.0', '$phi256.1', '$phi256.2', '$262compare_op.6']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=268, stack=('$phi256.0', '$phi256.1', '$phi256.2'), blockstack=(), npush=0), Edge(pc=274, stack=('$phi256.0', '$phi256.1', '$phi256.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=78 nstack_initial=1), State(pc_initial=472 nstack_initial=2), State(pc_initial=474 nstack_initial=2), State(pc_initial=164 nstack_initial=2), State(pc_initial=268 nstack_initial=3), State(pc_initial=274 nstack_initial=3)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=472 nstack_initial=2), State(pc_initial=474 nstack_initial=2), State(pc_initial=164 nstack_initial=2), State(pc_initial=268 nstack_initial=3), State(pc_initial=274 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi472.0', '$phi472.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=472 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=472, inst=JUMP_BACKWARD(arg=16, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi472.0', '$phi472.1']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=442, stack=('$phi472.0', '$phi472.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=474 nstack_initial=2), State(pc_initial=164 nstack_initial=2), State(pc_initial=268 nstack_initial=3), State(pc_initial=274 nstack_initial=3), State(pc_initial=442 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi474.0', '$phi474.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=474 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=474, inst=LOAD_FAST(arg=13, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi474.0', '$phi474.1']
# DEBUG:numba.core.byteflow:dispatch pc=476, inst=LOAD_FAST(arg=14, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi474.0', '$phi474.1', '$index474.2']
# DEBUG:numba.core.byteflow:dispatch pc=478, inst=COMPARE_OP(arg=40, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi474.0', '$phi474.1', '$index474.2', '$y476.3']
# DEBUG:numba.core.byteflow:dispatch pc=482, inst=POP_JUMP_IF_TRUE(arg=25, lineno=34)
# DEBUG:numba.core.byteflow:stack ['$phi474.0', '$phi474.1', '$478compare_op.4']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=484, stack=('$phi474.0', '$phi474.1'), blockstack=(), npush=0), Edge(pc=534, stack=('$phi474.0', '$phi474.1'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=164 nstack_initial=2), State(pc_initial=268 nstack_initial=3), State(pc_initial=274 nstack_initial=3), State(pc_initial=442 nstack_initial=2), State(pc_initial=484 nstack_initial=2), State(pc_initial=534 nstack_initial=2)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=268 nstack_initial=3), State(pc_initial=274 nstack_initial=3), State(pc_initial=442 nstack_initial=2), State(pc_initial=484 nstack_initial=2), State(pc_initial=534 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: ['$phi268.0', '$phi268.1', '$phi268.2']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=268 nstack_initial=3)
# DEBUG:numba.core.byteflow:dispatch pc=268, inst=LOAD_FAST(arg=5, lineno=20)
# DEBUG:numba.core.byteflow:stack ['$phi268.0', '$phi268.1', '$phi268.2']
# DEBUG:numba.core.byteflow:dispatch pc=270, inst=STORE_FAST(arg=12, lineno=20)
# DEBUG:numba.core.byteflow:stack ['$phi268.0', '$phi268.1', '$phi268.2', '$max_neg_val268.3']
# DEBUG:numba.core.byteflow:dispatch pc=272, inst=JUMP_FORWARD(arg=10, lineno=20)
# DEBUG:numba.core.byteflow:stack ['$phi268.0', '$phi268.1', '$phi268.2']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=294, stack=('$phi268.0', '$phi268.1', '$phi268.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=274 nstack_initial=3), State(pc_initial=442 nstack_initial=2), State(pc_initial=484 nstack_initial=2), State(pc_initial=534 nstack_initial=2), State(pc_initial=294 nstack_initial=3)])
# DEBUG:numba.core.byteflow:stack: ['$phi274.0', '$phi274.1', '$phi274.2']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=274 nstack_initial=3)
# DEBUG:numba.core.byteflow:dispatch pc=274, inst=LOAD_FAST(arg=8, lineno=22)
# DEBUG:numba.core.byteflow:stack ['$phi274.0', '$phi274.1', '$phi274.2']
# DEBUG:numba.core.byteflow:dispatch pc=276, inst=LOAD_FAST(arg=14, lineno=22)
# DEBUG:numba.core.byteflow:stack ['$phi274.0', '$phi274.1', '$phi274.2', '$value274.3']
# DEBUG:numba.core.byteflow:dispatch pc=278, inst=LOAD_CONST(arg=4, lineno=22)
# DEBUG:numba.core.byteflow:stack ['$phi274.0', '$phi274.1', '$phi274.2', '$value274.3', '$y276.4']
# DEBUG:numba.core.byteflow:dispatch pc=280, inst=BINARY_OP(arg=10, lineno=22)
# DEBUG:numba.core.byteflow:stack ['$phi274.0', '$phi274.1', '$phi274.2', '$value274.3', '$y276.4', '$const278.5']
# DEBUG:numba.core.byteflow:dispatch pc=284, inst=LOAD_FAST(arg=15, lineno=22)
# DEBUG:numba.core.byteflow:stack ['$phi274.0', '$phi274.1', '$phi274.2', '$value274.3', '$binop_sub280.6']
# DEBUG:numba.core.byteflow:dispatch pc=286, inst=BUILD_TUPLE(arg=2, lineno=22)
# DEBUG:numba.core.byteflow:stack ['$phi274.0', '$phi274.1', '$phi274.2', '$value274.3', '$binop_sub280.6', '$x284.7']
# DEBUG:numba.core.byteflow:dispatch pc=288, inst=BINARY_SUBSCR(arg=None, lineno=22)
# DEBUG:numba.core.byteflow:stack ['$phi274.0', '$phi274.1', '$phi274.2', '$value274.3', '$286build_tuple.8']
# ...
# DEBUG:numba.core.ssa:on stmt: branch $302pred, 304, 326
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 304
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: $const306.4 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $308compare_op.5 = y == $const306.4
# DEBUG:numba.core.ssa:on stmt: bool312 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $312pred = call bool312($308compare_op.5, func=bool312, args=(Var($308compare_op.5, core.py:24),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $312pred, 314, 320
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 314
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: v_prev.1 = const(float, 0.0)
# DEBUG:numba.core.ssa:on stmt: jump 352
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 320
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: v_prev.2 = max_neg_val
# DEBUG:numba.core.ssa:on stmt: jump 352
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 326
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: $const330.5 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub332.6 = y - $const330.5
# DEBUG:numba.core.ssa:on stmt: $const338.8 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub340.9 = x - $const338.8
# DEBUG:numba.core.ssa:on stmt: $344build_tuple.10 = build_tuple(items=[Var($binop_sub332.6, core.py:29), Var($binop_sub340.9, core.py:29)])
# DEBUG:numba.core.ssa:on stmt: v_prev.3 = getitem(value=value, index=$344build_tuple.10, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: jump 352
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 352
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: v_prev.4 = phi(incoming_values=[Var(v_prev.2, core.py:27), Var(v_prev.1, core.py:25), Var(v_prev.3, core.py:29)], incoming_blocks=[320, 314, 326])
# DEBUG:numba.core.ssa:on stmt: $358build_tuple.6 = build_tuple(items=[Var(y, core.py:17), Var(x, core.py:18)])
# DEBUG:numba.core.ssa:on stmt: $364binary_subscr.7 = getitem(value=value, index=$358build_tuple.6, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $368load_global.8 = global(max: <built-in function max>)
# DEBUG:numba.core.ssa:on stmt: $382call.12 = call $368load_global.8(v_prev.4, v_cur.3, func=$368load_global.8, args=[Var(v_prev.4, core.py:30), Var(v_cur.3, core.py:30)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $binop_iadd390.13 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=$364binary_subscr.7, rhs=$382call.12, static_lhs=Undefined, static_rhs=Undefined)
# DEBUG:numba.core.ssa:on stmt: value[$358build_tuple.6] = $binop_iadd390.13
# DEBUG:numba.core.ssa:on stmt: jump 252
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 404
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: jump 164
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 408
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: $410load_global.3 = global(range: <class 'range'>)
# DEBUG:numba.core.ssa:on stmt: $const422.6 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub424.7 = t_y - $const422.6
# DEBUG:numba.core.ssa:on stmt: $const428.8 = const(int, -1)
# DEBUG:numba.core.ssa:on stmt: $const430.9 = const(int, -1)
# DEBUG:numba.core.ssa:on stmt: $432call.10 = call $410load_global.3($binop_sub424.7, $const428.8, $const430.9, func=$410load_global.3, args=[Var($binop_sub424.7, core.py:32), Var($const428.8, core.py:32), Var($const430.9, core.py:32)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $440get_iter.11 = getiter(value=$432call.10)
# DEBUG:numba.core.ssa:on stmt: $phi442.1 = $440get_iter.11
# DEBUG:numba.core.ssa:on stmt: jump 442
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 442
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: $442for_iter.2 = iternext(value=$phi442.1)
# DEBUG:numba.core.ssa:on stmt: $442for_iter.3 = pair_first(value=$442for_iter.2)
# DEBUG:numba.core.ssa:on stmt: $442for_iter.4 = pair_second(value=$442for_iter.2)
# DEBUG:numba.core.ssa:on stmt: $phi446.2 = $442for_iter.3
# DEBUG:numba.core.ssa:on stmt: branch $442for_iter.4, 446, 546
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 446
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: y = $phi446.2
# DEBUG:numba.core.ssa:on stmt: $const448.3 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $456build_tuple.7 = build_tuple(items=[Var(y, core.py:17), Var(index, core.py:15)])
# DEBUG:numba.core.ssa:on stmt: path[$456build_tuple.7] = $const448.3
# DEBUG:numba.core.ssa:on stmt: $const464.9 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $466compare_op.10 = index != $const464.9
# DEBUG:numba.core.ssa:on stmt: bool470 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $470pred = call bool470($466compare_op.10, func=bool470, args=(Var($466compare_op.10, core.py:34),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $470pred, 474, 472
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 472
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: jump 551
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 474
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: $478compare_op.4 = index == y
# DEBUG:numba.core.ssa:on stmt: bool482 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $482pred = call bool482($478compare_op.4, func=bool482, args=(Var($478compare_op.4, core.py:34),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $482pred, 534, 484
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 484
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: $const488.4 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub490.5 = y - $const488.4
# DEBUG:numba.core.ssa:on stmt: $496build_tuple.7 = build_tuple(items=[Var($binop_sub490.5, core.py:34), Var(index, core.py:15)])
# DEBUG:numba.core.ssa:on stmt: $498binary_subscr.8 = getitem(value=value, index=$496build_tuple.7, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const506.11 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub508.12 = y - $const506.11
# DEBUG:numba.core.ssa:on stmt: $const514.14 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub516.15 = index - $const514.14
# DEBUG:numba.core.ssa:on stmt: $520build_tuple.16 = build_tuple(items=[Var($binop_sub508.12, core.py:34), Var($binop_sub516.15, core.py:34)])
# DEBUG:numba.core.ssa:on stmt: $522binary_subscr.17 = getitem(value=value, index=$520build_tuple.16, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $526compare_op.18 = $498binary_subscr.8 < $522binary_subscr.17
# DEBUG:numba.core.ssa:on stmt: bool530 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $530pred = call bool530($526compare_op.18, func=bool530, args=(Var($526compare_op.18, core.py:34),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $530pred, 534, 532
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 532
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: jump 551
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 534
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: $const536.3 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub538.4 = index - $const536.3
# DEBUG:numba.core.ssa:on stmt: index = $binop_sub538.4
# DEBUG:numba.core.ssa:replaced with: index.1 = $binop_sub538.4
# DEBUG:numba.core.ssa:on stmt: jump 551
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 546
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: jump 78
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 550
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: $const552.2 = const(NoneType, None)
# DEBUG:numba.core.ssa:on stmt: $552return_const.3 = cast(value=$const552.2)
# DEBUG:numba.core.ssa:on stmt: return $552return_const.3
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 551
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x319df4d10>
# DEBUG:numba.core.ssa:on stmt: jump 442
# DEBUG:numba.core.ssa:Replaced assignments: defaultdict(<class 'list'>,
#             {82: [<numba.core.ir.Assign object at 0x319cae870>],
#              534: [<numba.core.ir.Assign object at 0x31c7bc110>]})
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x319d8d3a0>
# DEBUG:numba.core.ssa:on stmt: paths = arg(0, name=paths)
# DEBUG:numba.core.ssa:on stmt: values = arg(1, name=values)
# DEBUG:numba.core.ssa:on stmt: t_ys = arg(2, name=t_ys)
# DEBUG:numba.core.ssa:on stmt: t_xs = arg(3, name=t_xs)
# DEBUG:numba.core.ssa:on stmt: $6load_attr.1 = getattr(value=paths, attr=shape)
# DEBUG:numba.core.ssa:on stmt: $const26.2 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: b = static_getitem(value=$6load_attr.1, index=0, index_var=$const26.2, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: max_neg_val = const(float, -1000000000.0)
# DEBUG:numba.core.ssa:on stmt: $38load_global.5 = global(range: <class 'range'>)
# DEBUG:numba.core.ssa:on stmt: $48load_global.7 = global(int: <class 'int'>)
# DEBUG:numba.core.ssa:on stmt: $60call.10 = call $48load_global.7(b, func=$48load_global.7, args=[Var(b, core.py:6)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $68call.11 = call $38load_global.5($60call.10, func=$38load_global.5, args=[Var($60call.10, core.py:8)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $76get_iter.12 = getiter(value=$68call.11)
# DEBUG:numba.core.ssa:on stmt: $phi78.0 = $76get_iter.12
# DEBUG:numba.core.ssa:on stmt: jump 78
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 78
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x319d8d3a0>
# DEBUG:numba.core.ssa:on stmt: $78for_iter.1 = iternext(value=$phi78.0)
# DEBUG:numba.core.ssa:on stmt: $78for_iter.2 = pair_first(value=$78for_iter.1)
# DEBUG:numba.core.ssa:on stmt: $78for_iter.3 = pair_second(value=$78for_iter.1)
# DEBUG:numba.core.ssa:on stmt: $phi82.1 = $78for_iter.2
# DEBUG:numba.core.ssa:on stmt: branch $78for_iter.3, 82, 550
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 82
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x319d8d3a0>
# DEBUG:numba.core.ssa:on stmt: i = $phi82.1
# DEBUG:numba.core.ssa:on stmt: path = getitem(value=paths, index=i, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: value = getitem(value=values, index=i, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: t_y = getitem(value=t_ys, index=i, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: t_x = getitem(value=t_xs, index=i, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: v_prev = const(float, 0.0)
# DEBUG:numba.core.ssa:on stmt: v_cur = v_prev
# DEBUG:numba.core.ssa:on stmt: $const134.16 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: index = t_x - $const134.16
# DEBUG:numba.core.ssa:on stmt: $142load_global.18 = global(range: <class 'range'>)
# DEBUG:numba.core.ssa:on stmt: $154call.21 = call $142load_global.18(t_y, func=$142load_global.18, args=[Var(t_y, core.py:11)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $162get_iter.22 = getiter(value=$154call.21)
# DEBUG:numba.core.ssa:on stmt: $phi164.1 = $162get_iter.22
# DEBUG:numba.core.ssa:on stmt: jump 164
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 164
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x319d8d3a0>
# DEBUG:numba.core.ssa:on stmt: $164for_iter.2 = iternext(value=$phi164.1)
# DEBUG:numba.core.ssa:on stmt: $164for_iter.3 = pair_first(value=$164for_iter.2)
# DEBUG:numba.core.ssa:on stmt: $164for_iter.4 = pair_second(value=$164for_iter.2)
# DEBUG:numba.core.ssa:on stmt: $phi168.2 = $164for_iter.3
# DEBUG:numba.core.ssa:on stmt: branch $164for_iter.4, 168, 408
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 168
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x319d8d3a0>
# DEBUG:numba.core.ssa:on stmt: y = $phi168.2
# DEBUG:numba.core.ssa:on stmt: $170load_global.3 = global(range: <class 'range'>)
# DEBUG:numba.core.ssa:on stmt: $180load_global.5 = global(max: <built-in function max>)
# DEBUG:numba.core.ssa:on stmt: $const190.7 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $binop_add196.10 = t_x + y
# DEBUG:numba.core.ssa:on stmt: $binop_sub202.12 = $binop_add196.10 - t_y
# DEBUG:numba.core.ssa:on stmt: $206call.13 = call $180load_global.5($const190.7, $binop_sub202.12, func=$180load_global.5, args=[Var($const190.7, core.py:18), Var($binop_sub202.12, core.py:18)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $214load_global.14 = global(min: <built-in function min>)
# DEBUG:numba.core.ssa:on stmt: $const228.18 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_add230.19 = y + $const228.18
# DEBUG:numba.core.ssa:on stmt: $234call.20 = call $214load_global.14(t_x, $binop_add230.19, func=$214load_global.14, args=[Var(t_x, core.py:12), Var($binop_add230.19, core.py:18)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $242call.21 = call $170load_global.3($206call.13, $234call.20, func=$170load_global.3, args=[Var($206call.13, core.py:18), Var($234call.20, core.py:18)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $250get_iter.22 = getiter(value=$242call.21)
# DEBUG:numba.core.ssa:on stmt: $phi252.2 = $250get_iter.22
# DEBUG:numba.core.ssa:on stmt: jump 252
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 252
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x319d8d3a0>
# DEBUG:numba.core.ssa:on stmt: $252for_iter.3 = iternext(value=$phi252.2)
# DEBUG:numba.core.ssa:on stmt: $252for_iter.4 = pair_first(value=$252for_iter.3)
# DEBUG:numba.core.ssa:on stmt: $252for_iter.5 = pair_second(value=$252for_iter.3)
# DEBUG:numba.core.ssa:on stmt: $phi256.3 = $252for_iter.4
# DEBUG:numba.core.ssa:on stmt: branch $252for_iter.5, 256, 404
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 256
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x319d8d3a0>
# DEBUG:numba.core.ssa:on stmt: x = $phi256.3
# DEBUG:numba.core.ssa:on stmt: $262compare_op.6 = x == y
# DEBUG:numba.core.ssa:on stmt: bool266 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $266pred = call bool266($262compare_op.6, func=bool266, args=(Var($262compare_op.6, core.py:19),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $266pred, 268, 274
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 268
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x319d8d3a0>
# DEBUG:numba.core.ssa:on stmt: v_cur.1 = max_neg_val
# DEBUG:numba.core.ssa:on stmt: jump 294
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 274
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x319d8d3a0>
# DEBUG:numba.core.ssa:on stmt: $const278.5 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $binop_sub280.6 = y - $const278.5
# DEBUG:numba.core.ssa:on stmt: $286build_tuple.8 = build_tuple(items=[Var($binop_sub280.6, core.py:22), Var(x, core.py:18)])
# DEBUG:numba.core.ssa:on stmt: v_cur.2 = getitem(value=value, index=$286build_tuple.8, fn=<built-in function getitem>)
